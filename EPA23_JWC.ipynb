# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexwcjung/EPA23/blob/main/EPA23_JWC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🍃 Warm up**

# %%
#@markdown ##🌎 Guess today's topic
from IPython.display import Image, display

image_url = 'https://raw.githubusercontent.com/Alexwcjung/EPA23/main/SETcWGVbZfYrGHmHfAZThUbpS8wIp9SzQlSrmfiqV5o-2eGwyPQ-OKnuK86C3S_T33w4hEKN1hQFGpDA1cjinA.webp'

display(Image(url=image_url, width=1000, height=800))
# Out:
# <img src="https://raw.githubusercontent.com/Alexwcjung/EPA23/main/SETcWGVbZfYrGHmHfAZThUbpS8wIp9SzQlSrmfiqV5o-2eGwyPQ-OKnuK86C3S_T33w4hEKN1hQFGpDA1cjinA.webp" width="1000" height="800"/>

# %%
#@markdown 🌱 Set-up: install, import libraries to use {pyqrcode, gtts, IPython, pandas, numpy, nltk, random}
# %%capture
# !pip install pyqrcode
# !pip install gtts
# !pip install wordcloud
# !pip install gradio
# !wget https://github.com/google/fonts/raw/main/ofl/nanumgothic/NanumGothic-Regular.ttf -O NanumGothic.ttf
# display, qr code
from IPython.display import YouTubeVideo, Image, Audio, display
# !pip install gtts
import pandas as pd
import pyqrcode
from pyqrcode import QRCode
from gtts import gTTS
from ipywidgets import widgets
import os
import numpy as np
import random
# wordcloud
# !pip install wordcloud nltk
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
english_stopwords = set(stopwords.words('english'))

import urllib.request

# %%
#@markdown ## 🎬 Empire State of Mind (https://www.youtube.com/watch?v=11hdtmneAVE)
from IPython.display import YouTubeVideo

vid = "11hdtmneAVE"
video = YouTubeVideo(vid, width = 800, height = 600)
display(video)

# %% [markdown]
# # **-----------------------------------------------------------------------------------------**

# %% [markdown]
# # **🍃 Lesson Objectives**
# ## 1. Students will be able to imitate native speaker's intonation on Praat.
# ## 2. Students will be able to demonstrate pronunciation difference with or without vowel insertion using Praat.

# %% [markdown]
# # **-----------------------------------------------------------------------------------------**

# %% [markdown]
# # **🍃 READING & LISTENING & WRITING**

# %%
#@markdown ## 🌎**NYC**
from IPython.display import Image, display

image_url = 'data:image/jpg;base64,...'

display(Image(url=image_url, width=800, height=800))
# Out:
# <img src="data:image/jpg;base64,..." width="800" height="800"/>

# %%
#@markdown ## 🌎**Text to Speech**

def tts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")
mytext = input("Type text: ")
tts(mytext)
# Out:
# Type text: Time square is a big intersection in the city center
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **🍃 SPEAKING**

# %%
#@markdown ## **🌎 Speak by yourself [1] - formative assessment**
#@markdown ## Step 1. Choose one of the places you want to go in the reading passage
#@markdown ## Step 2. Record on Praat.
#@markdown ## 📋 Praat download QR Code
#@markdown ## ✅ Rubric : Your speech intonation should closely resemble that of a native speaker. For each instance where your pitch curve on Praat shows the opposite direction of that of a native speaker, three points will be deducted.
# !pip install pyqrcode
#@markdown ## ✅ Feedback : The image of your pitch wave will be compared with that of the native speaker on TTS. Differences will be identified and posted on Padlet for your reference.

import pyqrcode
from pyqrcode import QRCode

s = input("Paste the link: ")

url = pyqrcode.create(s)

url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Paste the link: https://www.fon.hum.uva.nl/praat/download_win.html

# %%
#@markdown ## 🌎**Translation (Extra resources for self-study)**
# !pip install googletrans==4.0.0-rc1

from googletrans import Translator

# Create an instance of the Translator
translator = Translator(service_urls=['translate.google.com'])

# Input the English sentence to be translated
text = input("Enter the English sentence to translate: ")

# Specify the source and target languages
source_lang = 'en'
target_lang = 'ko'

# Translate the text to the target language
translated_text = translator.translate(text, src=source_lang, dest=target_lang)

# Print the translated text
print(f"Original text: {text}")
print(f"Translated text: {translated_text.text}")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.3 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=5aaea2b5ee2121a865cb72c71b0d694fd237ee1723f91630631b607d13135452
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# ...

# %% [markdown]
# ## 🌎 **Speak by yourself [2]** - Summative assessment
# ## Step 1: Select seven words commonly prone to vowel insertion by Korean speakers (e.g., site, cake).
# ## Step 2: Utilize Praat to record your pronunciation. When pronouncing each word, you should (1) pronounce it with vowel insertion and (2) pronounce it without vowel insertion. Aim to demonstrate the difference between (1) and (2) as distinctly as possible.
# ### ✅ Rubric : For each instance where it is determined that you added a vowel to a consonant in your waveform, two points will be deducted.
# ### ✅ Feedback : The image of your pitch wave will be compared with that of a native speaker. Discrepancies will be identified, marked, and posted on Padlet for your review.

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **🍃Homework**

# %% [markdown]
# ## 1. Upload your travel plan to NYC on Padlet. Refer to the links below and use ChatGPT
# ### (1) [NYC Tour](https://www.pinterest.co.kr/pin/216454325832639584/)
# ### (2) [NYC Tour](https://www.pinterest.co.kr/pin/47076758599920678/)
# ### (3) [NYC Tour](https://www.pinterest.co.kr/pin/346636502585167812/)
# ### (4) [ChatGPT](https://chat.openai.com/)
#
# ## 2. Read aloud your travel plan on [Speechnotes] (Remember the intonation and vowel insertion rule) (https://speechnotes.co/)

# %%
#@markdown ## 📋 Padlet QR Code
# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

s = input("Paste the link: ")

url = pyqrcode.create(s)

url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Paste the link: https://ko.padlet.com/alexwcjung1130/padlet-ntuglot152x0dgkb

# %% [markdown]
# # **🍃See you next time~**
